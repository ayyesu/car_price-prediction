# %%
import pandas as pd
import numpy as np

# %% [markdown]
# DATA PREPARATION

# %%
data = 'https://raw.githubusercontent.com/ayyesu/car_price-prediction/main/data.csv'

# %%
df = pd.read_csv('./data/data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# make                 object
# model                object
# engine_fuel_type     object
# transmission_type    object
# driven_wheels        object
# market_category      object
# vehicle_size         object
# vehicle_style        object
# dtype: object

# %%
index_str = list(df.dtypes[df.dtypes == 'object'].index)
index_str
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in index_str:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
for col in df:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
#
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
#
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# city_mpg
# [19 20 18 17 16]
# 69
#
# popularity
# [3916 3105  819  617 1013]
# 48
#
# msrp
# [46135 40650 36350 29450 34500]
# 6049

# %% [markdown]
# Distribution of Price

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.histplot(df.msrp, bins=40)
# Out:
# C:\Users\iamda\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\iamda\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins=40)
# Out:
# C:\Users\iamda\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\iamda\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='msrp', ylabel='Count'>

# %% [markdown]
# This distribution may confuse the model due to the price difference. Looking at the tail of the chart. Less people tend to buy expensive cars but that doesn't mean no one can buy those cars.
#
# So we get rid of the price differences using the log function in numpy

# %%
# log transformation to remove the long tail from price
price_logs = np.log1p(df.msrp)
sns.histplot(price_logs, bins=40)
# Out:
# C:\Users\iamda\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\iamda\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='msrp', ylabel='Count'>

# %% [markdown]
# Missing values

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
df.isnull()
# Out:
#         make  model   year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0      False  False  False             False      False             False
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11909  False  False  False             False      False             False
# 11910  False  False  False             False      False             False
# 11911  False  False  False             False      False             False
# 11912  False  False  False             False      False             False
# 11913  False  False  False             False      False             False
#
#        transmission_type  driven_wheels  number_of_doors  market_category  \
# 0                  False          False            False            False
# 1                  False          False            False            False
# 2                  False          False            False            False
# 3                  False          False            False            False
# 4                  False          False            False            False
# ...                  ...            ...              ...              ...
# 11909              False          False            False            False
# 11910              False          False            False            False
# 11911              False          False            False            False
# 11912              False          False            False            False
# 11913              False          False            False            False
#
#        vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 0             False          False        False     False       False  False
# 1             False          False        False     False       False  False
# 2             False          False        False     False       False  False
# 3             False          False        False     False       False  False
# 4             False          False        False     False       False  False
# ...             ...            ...          ...       ...         ...    ...
# 11909         False          False        False     False       False  False
# 11910         False          False        False     False       False  False
# 11911         False          False        False     False       False  False
# 11912         False          False        False     False       False  False
# 11913         False          False        False     False       False  False
#
# [11914 rows x 16 columns]

# %%
index_str
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
# One hot encoding
df = pd.get_dummies(df, columns=index_str)

# %%
df.head()
# Out:
#    year  engine_hp  engine_cylinders  number_of_doors  highway_mpg  city_mpg  \
# 0  2011      335.0               6.0              2.0           26        19
# 1  2011      300.0               6.0              2.0           28        19
# 2  2011      300.0               6.0              2.0           28        20
# 3  2011      230.0               6.0              2.0           28        18
# 4  2011      230.0               6.0              2.0           28        18
#
#    popularity   msrp  make_acura  make_alfa_romeo  ...  \
# 0        3916  46135       False            False  ...
# 1        3916  40650       False            False  ...
# 2        3916  36350       False            False  ...
# 3        3916  29450       False            False  ...
# 4        3916  34500       False            False  ...
#
#    vehicle_style_convertible  vehicle_style_convertible_suv  \
# 0                      False                          False
# 1                       True                          False
# 2                      False                          False
# 3                      False                          False
# 4                       True                          False
#
#    vehicle_style_coupe  vehicle_style_crew_cab_pickup  \
# 0                 True                          False
# 1                False                          False
# 2                 True                          False
# 3                 True                          False
# 4                False                          False
#
#    vehicle_style_extended_cab_pickup  vehicle_style_passenger_minivan  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
#
#    vehicle_style_passenger_van  vehicle_style_regular_cab_pickup  \
# 0                        False                             False
# 1                        False                             False
# 2                        False                             False
# 3                        False                             False
# 4                        False                             False
#
#    vehicle_style_sedan  vehicle_style_wagon
# 0                False                False
# 1                False                False
# 2                False                False
# 3                False                False
# 4                False                False
#
# [5 rows x 1079 columns]

# %%
df.isna().sum()
# Out:
# year                                 0
# engine_hp                           69
# engine_cylinders                    30
# number_of_doors                      6
# highway_mpg                          0
#                                     ..
# vehicle_style_passenger_minivan      0
# vehicle_style_passenger_van          0
# vehicle_style_regular_cab_pickup     0
# vehicle_style_sedan                  0
# vehicle_style_wagon                  0
# Length: 1079, dtype: int64

# %%
# Fill NaN values with mean of its column
df.fillna(df.mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# year                                0
# engine_hp                           0
# engine_cylinders                    0
# number_of_doors                     0
# highway_mpg                         0
#                                    ..
# vehicle_style_passenger_minivan     0
# vehicle_style_passenger_van         0
# vehicle_style_regular_cab_pickup    0
# vehicle_style_sedan                 0
# vehicle_style_wagon                 0
# Length: 1079, dtype: int64

# %% [markdown]
# Setting Up Validation Environment

# %%
# Shuffle the entire DataFrame
df_shuffle = df.sample(frac=1).reset_index(drop=True)

# Calculate sizes for validation and test sets
n_val = int(len(df_shuffle) * 0.2) # 20% for validation

n_test = int(len(df_shuffle) * 0.2) # 20% for test

# %%
# Split the shuffled DataFrame
df_val = df_shuffle.iloc[:n_val]
df_test = df_shuffle.iloc[n_val:n_val+n_test]
df_train = df_shuffle.iloc[n_val+n_test:]

# %%
# Reset index for each DataFrame
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_train = df_train.reset_index(drop=True)

# %%
# Checking the length of each DataFrame after shuffle
len(df_val), len(df_test), len(df_train)
# Out:
# (2382, 2382, 7150)

# %%
# Apply logarithmic transformation with an offset of 1 to the target variable (msrp) for each dataset
y_val = np.log1p(df_val.msrp.values)    # Log-transform validation set target
y_test = np.log1p(df_test.msrp.values)  # Log-transform test set target
y_train = np.log1p(df_train.msrp.values)  # Log-transform training set target

# %%
# Since we don't want to repeat (msrp) as a feature in out DataFrame we delete it
del df_val['msrp']
del df_test['msrp']
del df_train['msrp']

# %%
# Save DataFrames as CSV files
df_val.to_csv('./data/df_val.csv', index=False)
df_test.to_csv('./data/df_test.csv', index=False)
df_train.to_csv('./data/df_train.csv', index=False)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df_train
# Out:
#       year  engine_hp  engine_cylinders  number_of_doors  highway_mpg  \
# 0     2016      202.0               4.0              4.0           32
# 1     2012      122.0               4.0              4.0           30
# 2     2016      170.0               4.0              4.0           35
# 3     2010      162.0               4.0              2.0           27
# 4     2015      300.0               6.0              4.0           30
# ...    ...        ...               ...              ...          ...
# 7145  2003      225.0               8.0              3.0           15
# 7146  2017      188.0               4.0              4.0           41
# 7147  2014      210.0               4.0              4.0           33
# 7148  2000      290.0               8.0              4.0           23
# 7149  2016      224.0               6.0              4.0           27
#
#       city_mpg  popularity  make_acura  make_alfa_romeo  make_aston_martin  \
# 0           22        1624       False            False              False
# 1           25        2009       False            False              False
# 2           25         873       False            False              False
# 3           20         436       False            False              False
# 4           18        1385       False            False              False
# ...        ...         ...         ...              ...                ...
# 7145        13        1851       False            False              False
# 7146        43        5657       False            False              False
# 7147        23         873       False            False              False
# 7148        16         454       False            False              False
# 7149        20         436       False            False              False
#
#       ...  vehicle_style_convertible  vehicle_style_convertible_suv  \
# 0     ...                      False                          False
# 1     ...                      False                          False
# 2     ...                      False                          False
# 3     ...                      False                          False
# 4     ...                      False                          False
# ...   ...                        ...                            ...
# 7145  ...                      False                          False
# 7146  ...                      False                          False
# 7147  ...                      False                          False
# 7148  ...                      False                          False
# 7149  ...                      False                          False
#
#       vehicle_style_coupe  vehicle_style_crew_cab_pickup  \
# 0                   False                          False
# 1                   False                          False
# 2                   False                          False
# 3                   False                          False
# 4                   False                          False
# ...                   ...                            ...
# 7145                False                          False
# 7146                False                          False
# 7147                False                          False
# 7148                False                          False
# 7149                False                          False
#
#       vehicle_style_extended_cab_pickup  vehicle_style_passenger_minivan  \
# 0                                 False                            False
# 1                                 False                            False
# 2                                 False                            False
# 3                                 False                            False
# 4                                 False                            False
# ...                                 ...                              ...
# 7145                              False                            False
# 7146                              False                            False
# 7147                              False                            False
# 7148                              False                            False
# 7149                              False                            False
#
#       vehicle_style_passenger_van  vehicle_style_regular_cab_pickup  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
# ...                           ...                               ...
# 7145                        False                             False
# 7146                        False                             False
# 7147                        False                             False
# 7148                        False                             False
# 7149                        False                             False
#
#       vehicle_style_sedan  vehicle_style_wagon
# 0                    True                False
# 1                   False                 True
# 2                   False                 True
# 3                   False                False
# 4                    True                False
# ...                   ...                  ...
# 7145                False                False
# 7146                 True                False
# 7147                 True                False
# 7148                 True                False
# 7149                False                False
#
# [7150 rows x 1078 columns]

# %%
pipe = Pipeline([
    ("scale", StandardScaler()),
    ("model", LinearRegression())
])
# Out:
# {'memory': None,
#  'steps': [('scale', StandardScaler()), ('model', LinearRegression())],
#  'verbose': False,
#  'scale': StandardScaler(),
#  'model': LinearRegression(),
#  'scale__copy': True,
#  'scale__with_mean': True,
#  'scale__with_std': True,
#  'model__copy_X': True,
#  'model__fit_intercept': True,
#  'model__n_jobs': None,
#  'model__positive': False}

# %%
# train model
model = Ridge(alpha=.1)
model.fit(df_train, y_train)

# make prediction on test set
y_pred = model.predict(df_test)

# %%
predicted_prices = np.expm1(y_pred)
predicted_prices
# Out:
# array([73086.20759687,  2090.50492113, 30015.38401949, ...,
#        18897.59537435, 24296.05787177, 17059.5164701 ])

# %%
actual_prices = np.expm1(y_test)
actual_prices
# Out:
# array([78820.,  2000., 32580., ..., 20410., 28120., 20755.])

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE: ", mse*100)
print("Accuracy: ", r2*100)
# Out:
# MSE:  4.669440030614185
# Accuracy:  95.95524955819451

# %%
# Plotting the linear line of the model
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], color='red', linestyle='--', linewidth=2)
plt.title('Actual vs. Predicted MSRP')
plt.xlabel('Actual MSRP')
plt.ylabel('Predicted MSRP')
plt.show()

# %%
df_val.head()
# Out:
#    year  engine_hp  engine_cylinders  number_of_doors  highway_mpg  city_mpg  \
# 0  1991  130.00000               4.0              4.0           26        18
# 1  2014  270.00000               6.0              4.0           22        17
# 2  2003  108.00000               4.0              2.0           36        28
# 3  2016  249.38607               6.0              4.0           25        17
# 4  1991  150.00000               6.0              4.0           18        14
#
#    popularity  make_acura  make_alfa_romeo  make_aston_martin  ...  \
# 0         617       False            False              False  ...
# 1        2031       False            False              False  ...
# 2        2031       False            False              False  ...
# 3        1385       False            False              False  ...
# 4         549       False            False              False  ...
#
#    vehicle_style_convertible  vehicle_style_convertible_suv  \
# 0                      False                          False
# 1                      False                          False
# 2                      False                          False
# 3                      False                          False
# 4                      False                          False
#
#    vehicle_style_coupe  vehicle_style_crew_cab_pickup  \
# 0                False                          False
# 1                False                          False
# 2                 True                          False
# 3                False                          False
# 4                False                          False
#
#    vehicle_style_extended_cab_pickup  vehicle_style_passenger_minivan  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
#
#    vehicle_style_passenger_van  vehicle_style_regular_cab_pickup  \
# 0                        False                             False
# 1                        False                             False
# 2                        False                             False
# 3                        False                             False
# 4                        False                             False
#
#    vehicle_style_sedan  vehicle_style_wagon
# 0                 True                False
# 1                False                False
# 2                False                False
# 3                 True                False
# 4                False                False
#
# [5 rows x 1078 columns]

# %%
# Predicting our validation dataset
new_pred = model.predict(df_val)
pred_msrp = np.expm1(new_pred)
pred_msrp
# Out:
# array([ 1778.77541709, 37125.81745727, 10794.3963207 , ...,
#         2304.07975467, 29949.76266911, 36953.43270777])

# %%
# Actual Price for Validation dataset
actual_msrp = np.expm1(y_val)
actual_msrp
# Out:
# array([ 2000., 37615., 11045., ...,  2301., 29265., 39375.])
